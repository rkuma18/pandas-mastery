# %% [markdown]
# # Operators (& Dunder Methods)

# %% [markdown]
# ### 1. Dunder Methods / Magic Methods

# %%
(2).__add__(4)
# Out:
# 6

# %%
import pandas as pd
url = '/Users/rkuma18/Developer/data-science/Pandas/Dataset/vehicles.csv'
df = pd.read_csv(url)
city_mpg = df.city08
highway_mpg = df.highway08
# Out:
# /var/folders/cf/p1jrzc9j3gv2n7dg377g4_cw0000gn/T/ipykernel_19881/2808278316.py:3: DtypeWarning: Columns (69,71,72,73,74,75,77,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
(city_mpg + highway_mpg) /2
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 49575    22.5
# 49576    24.0
# 49577    21.0
# 49578    21.0
# 49579    18.5
# Length: 49580, dtype: float64

# %% [markdown]
# ### 2. Index Alignment

# %%
s1 = pd.Series([10,20,30], index=[1,2,2])
s2 = pd.Series([35,44,53], index=[2,2,4], name='s2')

# %%
s1
# Out:
# 1    10
# 2    20
# 2    30
# dtype: int64

# %%
s2
# Out:
# 2    35
# 2    44
# 4    53
# Name: s2, dtype: int64

# %%
s1 + s2
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %% [markdown]
# `Note` : index names 1 and 4 have `NaN` while index name 2 has four results every 2 from s1 is matched up with every 2 from s2

# %% [markdown]
# ### 3. Broadcasting

# %% [markdown]
# When we perfrom math operations with a scalar, pandas `broadcasts` the operation to all value

# %%
s1.add(s2,fill_value=0)
# Out:
# 1    10.0
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4    53.0
# dtype: float64

# %% [markdown]
# ### 4. Operator Method

# %% [markdown]
# `fill_value` : The operator methods have `fill_value` parameter that changes this behavior. If operands is missing, it will use the fill_value insted

# %% [markdown]
# ### 5. Chaining

# %%
(city_mpg
.add(highway_mpg)
.div(2))
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 49575    22.5
# 49576    24.0
# 49577    21.0
# 49578    21.0
# 49579    18.5
# Length: 49580, dtype: float64
