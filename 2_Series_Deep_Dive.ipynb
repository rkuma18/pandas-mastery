# %% [markdown]
# # Series Deep Dive

# %% [markdown]
# ### 1. Loading the Data

# %%
import pandas as pd

# %%
url = '/Users/rkuma18/Developer/data-science/Pandas/Dataset/vehicles.csv'
df = pd.read_csv(url)
city_mpg = df.city08
highway_mpg = df.highway08
# Out:
# /var/folders/cf/p1jrzc9j3gv2n7dg377g4_cw0000gn/T/ipykernel_13446/1290116512.py:2: DtypeWarning: Columns (69,71,72,73,74,75,77,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
city_mpg
# Out:
# 0        19
# 1         9
# 2        23
# 3        10
# 4        17
#          ..
# 49575    19
# 49576    20
# 49577    18
# 49578    18
# 49579    16
# Name: city08, Length: 49580, dtype: int64

# %%
highway_mpg
# Out:
# 0        25
# 1        14
# 2        33
# 3        12
# 4        23
#          ..
# 49575    26
# 49576    28
# 49577    24
# 49578    24
# 49579    21
# Name: highway08, Length: 49580, dtype: int64

# %% [markdown]
# ### 2. Series Atrributes

# %%
len(dir(city_mpg))
# Out:
# 422
